# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# Print the current working directory
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /home/gs/code/high-density-eeg-analysis/Tinysleepnet-pytorch

# %%
# Load the .npz file
data = np.load('./out_sleepedf/predict/pred_SC4001E0.npz')

# Assuming the .npz file contains arrays, you can list the keys
print(data.files)

# Visualize the data
# Replace 'array_name' with the actual key from the .npz file
array_name = 'y_true'
array_data = data[array_name]

plt.figure(figsize=(10, 6))
plt.plot(data['y_true'], label='True')
plt.plot(data['y_pred'], label='Predicted')
plt.title(f'Visualization of {array_name}')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
# Out:
# ['y_true', 'y_pred']
